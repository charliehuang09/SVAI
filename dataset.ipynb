# %%
import pandas as pd
import numpy as np
from dataset import to_numpy
import matplotlib.pyplot as plt
from dataset import Dataset
from config import ModelType
from sklearn.preprocessing import normalize
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = Dataset("Train", 0.8, ModelType.Regression)
# Out:
# Loading Train Dataset
# Train Range: 0-66320
# X shape: torch.Size([66320, 8])
# Y shape: torch.Size([66320])
# Length: 66320
# Finished Loading Dataset

# %%
x = dataset.getx()

# %%
y = dataset.gety()

# %%
plt.plot(y)

# %%
plt.plot(x[:, 0])

# %%
plt.plot(x[:, 1]) # population

# %%
plt.plot(x[:, 2]) # rain

# %%
plt.plot(x[:, 3]) # biomass

# %%
plt.plot(x[:, 4]) # humidity

# %%
plt.plot(x[:, 5]) # wind

# %%
plt.plot(x[:, 6]) # soil_moisture
plt.show()
print(x[:20, 6])
plt.hist(x[:, 6])
plt.show()
# Out:
# tensor([6.4410e-01, 6.4410e-01, 7.8646e-01, 5.7292e-01, 5.4861e-01, 4.2708e-01,
#         7.1181e-02, 2.5635e-22, 2.6303e-22, 2.6117e-22, 2.5860e-22, 2.5526e-22,
#         2.5679e-22, 2.5364e-22, 2.5563e-22, 2.5845e-22, 2.5888e-22, 2.5695e-22,
#         2.5575e-22, 2.5751e-22])

# %%
plt.plot(x[:, 7]) # temperature
