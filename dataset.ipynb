# %%
import matplotlib.pyplot as plt
from dataset import Dataset

# %%
dataset = Dataset("Train", 0.8, 'Regression')
# Out:
# Loading Train Dataset
# Train Range: 0-55472
# X shape: torch.Size([55472, 8])
# Y shape: torch.Size([55472])
# Length: 55472
# Finished Loading Dataset

# %%
x = dataset.getx()

# %%
y = dataset.gety()

# %%
plt.plot(y)

# %%
plt.plot(x[:, 0])

# %%
plt.plot(x[:, 1]) # population

# %%
plt.plot(x[:, 2]) # rain

# %%
plt.plot(x[:, 3]) # biomass

# %%
plt.plot(x[:, 4]) # humidity

# %%
plt.plot(x[:, 5]) # wind

# %%
plt.plot(x[:, 6]) # soil_moisture
plt.show()
print(x[:20, 6])
plt.hist(x[:, 6])
plt.show()
# Out:
# tensor([8.5417e-01, 1.4236e-01, 5.1270e-22, 5.2605e-22, 5.2233e-22, 5.1719e-22,
#         5.1052e-22, 5.1358e-22, 5.0727e-22, 5.1127e-22, 5.1690e-22, 5.1776e-22,
#         5.1391e-22, 5.1151e-22, 5.1501e-22, 5.1506e-22, 5.1389e-22, 5.1397e-22,
#         5.1603e-22, 7.4653e-01])

# %%
plt.plot(x[:, 7]) # temperature
