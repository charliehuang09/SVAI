# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
preds = np.load('metrics/preds.npy')
gt = np.load('metrics/ground_truth.npy')

# %% [markdown]
# **Annual Average**

# %%
plt.plot(preds, label='Predictions')
plt.plot(gt, label='Ground Truth')
plt.legend()

# %% [markdown]
# **Train**

# %%
fig = plt.imshow(plt.imread('metrics/train_scatter.png'))
plt.axis('off')
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %% [markdown]
# **Valid**

# %%
fig = plt.imshow(plt.imread('metrics/valid_scatter.png'))
plt.axis('off')
# Out:
# (-0.5, 639.5, 479.5, -0.5)
